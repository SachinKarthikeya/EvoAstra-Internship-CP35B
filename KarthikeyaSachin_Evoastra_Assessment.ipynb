# %% [markdown]
# # Evoastra Ventures Intern Assessment Task
# **Duration: 35 Minutes | Total Points: 100**
#
# ---

# %% [markdown]
# ## **Candidate Information**
#
# **Fill in your details below:**
# - **Name:** Vemuganti Karthikeya Sachin
# - **Email:** sachinkarthikeya@gmail.com
# - **Phone:** 9666300958
# - **College/University:** GITAM University Hyderabad
# - **Course/Branch:** B.Tech Computer Science and Engineering (AIML)
# - **Start Time:** 1:50 P.M.
# - **End Time:** 2:50 P.M.

# %% [markdown]
# ## **Dataset for Assessment**
#
# **E-commerce Customer Behavior Dataset**
# - **Direct Link:** https://www.kaggle.com/datasets/shriyashjagtap/e-commerce-customer-for-behavior-analysis
#
# **Dataset Columns:**
# - **Customer ID:** Unique identifier for each customer
# - **Customer Name:** Name of the customer
# - **Customer Age:** Age of the customer
# - **Gender:** Gender of the customer
# - **Purchase Date:** Date of each purchase
# - **Product Category:** Category of the purchased product
# - **Product Price:** Price of the purchased product
# - **Quantity:** Quantity of product purchased
# - **Total Purchase Amount:** Total amount spent in each transaction
# - **Payment Method:** Payment method used (credit card, PayPal, etc.)
# - **Returns:** Whether customer returned products (0 = No, 1 = Yes)
# - **Churn:** Whether customer has churned (0 = Retained, 1 = Churned)

# %% [markdown]
# ---
# ## **SECTION A: Data Understanding & Basic Analysis (25 Points - 10 Minutes)**

# %% [markdown]
# ### Question 1 (8 points)
# Based on the dataset structure, identify the **data types** for the following columns and explain why each classification is important for analysis:
#
# - **Customer Age**
# - **Gender**
# - **Total Purchase Amount**
# - **Churn**

# %%
# Your Answer for Question 1
# Customer Age: Int. Customer age is important because it can help analyze purchasing behavior among different age groups.

# Gender: String. Gender is important because it can help identify which gender is more likely to purchase certain products, which can be beneficial for marketing campaigns.

# Total Purchase Amount: Float. Total purchase amount is important because it can help identify high-value customers and strategize marketing efforts accordingly.

# Churn: Boolean. Churn is important because it indicates whether a customer has stopped using a specific product, which is useful for retain strategies.

# %% [markdown]
# ### Question 2 (8 points)
# Which **analytical technique** would be most appropriate for each business question below?
#
# a) "Which product categories generate the highest revenue?"
# b) "Can we predict customer churn based on purchase behavior?"
# c) "What is the relationship between customer age and spending patterns?"
# d) "Which payment methods are preferred by different customer segments?"

# %%
# Your Answer for Question 2
# a) Product categories with highest revenue: Descriptive analysis such as statistical summaries can help identify which product categories generate the highest revenue.

# b) Predicting customer churn: Developing an ML model to predict which customers are likely to churn based on their purchase history and demographics.

# c) Age and spending relationship: Correlation analysis can help visualize the relationship between customer age and spending patterns.

# d) Payment method preferences: Analyzing the distribution of payment methods used by customers can help identify different customer segments..

# %% [markdown]
# ### Question 3 (9 points)
# **Data Quality Assessment:** What are the top 3 potential data quality issues you would check for in this e-commerce dataset before starting analysis? For each issue, suggest one method to detect it.

# %%
# Your Answer for Question 3
# Issue 1: Presence of missing values in important columns

# Detection Method 1: Checking for null values in the dataset using the "isnull()" function in Pandas.

# Issue 2: Imbalanced no of values in the target variable

# Detection Method 2: Analyzing the distribution of the target variable to check for class imbalance.

# Issue 3: Imbalanced ranges of numerical values in several columns of the dataset

# Detection Method 3: Using the "describe()" function in Pandas to analyze the statistical distribution of numerical features.

# %% [markdown]
# ---
# ## **SECTION B: Customer Analysis & Business Intelligence (35 Points - 15 Minutes)**

# %% [markdown]
# ### Scenario: E-commerce Revenue Analysis
#
# Based on the dataset structure, assume you have the following customer insights:
#
# **Customer Segments by Age:**
# - **Young (18-30):** 40% of customers, Average Purchase Amount: ₹850, Return Rate: 12%
# - **Middle-aged (31-50):** 45% of customers, Average Purchase Amount: ₹1,200, Return Rate: 8%
# - **Senior (51+):** 15% of customers, Average Purchase Amount: ₹950, Return Rate: 15%
#
# **Additional Information:**
# - Average customer acquisition cost: ₹180
# - Platform profit margin: 20% of purchase amount
# - Customer churn rates: Young (25%), Middle-aged (15%), Senior (30%)

# %% [markdown]
# ### Question 4 (15 points)
# **Calculate and analyze:**
#
# a) Which customer segment generates the highest **net profit per customer** (considering returns)? Show your calculations. (8 points)
#
# b) Which segment has the **best customer lifetime value** considering churn rates? Provide reasoning. (7 points)

# %%
# Your Calculations for Question 4

# a) Net profit per customer calculations: 

# Young Customers: −10.4

# Middle-aged Customers: 40.8

# Senior Customers: −18.5

# b) Customer Lifetime Value Analysis: As per the above analysis, Middle-aged customers have the highest net profit of 40.8 rupees, meaning they have the best customer lifetime value.

# %% [markdown]
# ### Question 5 (10 points)
# **Strategic Recommendations:** Based on your analysis, what would be your **top 2 marketing strategies** to maximize overall profitability? Consider customer acquisition, retention, and return rates.

# %%
# Your Answer for Question 5

# Strategy 1: Target marketing campaigns mainly focusing on middle-aged customers, as they have the highest net profit and customer lifetime value.

# Strategy 2: Implement loyalty programs for middle-aged customers to increase customer lifetime value.

# %% [markdown]
# ### Question 6 (10 points)
# **Churn Prevention:** You notice that customers who make purchases in the "Electronics" category have a 35% churn rate, while "Fashion" category customers have only 18% churn rate. What **specific data analysis** would you conduct using the available dataset columns to understand this difference, and what **action plan** would you recommend?

# %%
# Your Answer for Question 6

# Data Analysis Plan: Implement Exploratory Data Analysis to understand customer demographics, purchasing behavior, and churn patterns between different customer groups, mainly focusing on age and gender features.

# Action Plan: Target marketing campaigns, mainly focusing on fashion products for young customers, especially women, as they have a higher likelihood of purchasing fashion items.

# %% [markdown]
# ---
# ## **SECTION C: Research Methodology & Predictive Analytics (25 Points - 8 Minutes)**

# %% [markdown]
# ### Scenario: Churn Prediction Model Development
#
# Your company wants to build a machine learning model to predict customer churn using the available dataset.

# %% [markdown]
# ### Question 7 (15 points)
# **Model Development Plan:** Create a comprehensive approach including:
#
# a) **Feature selection:** Which columns from the dataset would you use as features for the churn prediction model and why? (5 points)
# b) **Data preprocessing steps:** What preprocessing would you apply to prepare the data? (5 points)
# c) **Model evaluation metrics:** Which metrics would you use to evaluate model performance for this business problem? (5 points)

# %%
# Your Answer for Question 7

# a) Feature Selection: I would mainly use features like Product Category, Total Purchase Amount, Payment Method, Customer Age, Returns, Age, Gender to for building my customer churn prediction model.

# b) Data Preprocessing Steps: I would use data pre-processing steps like handling missing values, encoding categorical features like product category and payment method, and scaling numerical features for efficient distribution of data.

# c) Model Evaluation Metrics: As this is a classification-based problem, I would use evaluation metrics like accuracy, precision, recall, and F1-score to evaluate the performance of my customer churn prediction model.

# %% [markdown]
# ### Question 8 (10 points)
# **Business Impact Analysis:** Identify 3 potential business challenges in implementing a churn prediction model and propose one **data-driven solution** for each challenge using insights from the customer behavior dataset.

# %%
# Your Answer for Question 8

# Challenge 1: Poor data quality due to missing or inconsistent values, imbalanced range of values in the columns can affect the prediction of customer churn value. 
# Data-driven Solution 1: For this, implementing data cleaning and preprocessing techniques can help improve data quality.

# Challenge 2: A large number of values in the dataset can lead to poor analysis, slow training time, leading to increase in computational costs.
# Data-driven Solution 2: For this, using feature selection can be beneficial, which reduces the number of features in the dataset by taking only the important ones.

# Challenge 3: As customer preferences and behaviors change over time, models trained on older data may become less accurate.
# Data-driven Solution 3: For this, regularly updating the model with new data and retraining it can help maintain its accuracy.

# %% [markdown]
# ---
# ## **SECTION D: Professional Communication & Problem-Solving (15 Points - 2 Minutes)**

# %% [markdown]
# ### Question 9 (8 points)
# **Crisis Management:** While analyzing the dataset, you discover that 40% of customers who returned products (Returns = 1) also churned within the same month. However, your initial analysis showed returns don't strongly correlate with churn. As a team member, describe your immediate approach to investigate this discrepancy and communicate findings to stakeholders (60-80 words).

# %%
# Your Answer for Question 9 (60-80 words)
#The most effective approach would be to conduct a detailed statistical analysis on customer return status and churning behaviour and preparing a report summarizing the findings which can be presented to the stakeholders.

# %% [markdown]
# ### Question 10 (7 points)
# **Leadership Scenario:** If selected as team lead for analyzing this e-commerce customer dataset, what would be your **top 3 priorities** to ensure effective team collaboration and delivery of actionable business insights?

# %%
# Your Answer for Question 10

# Priority 1: Ensure efficient data cleaning and pre processing techniques to improve quality

# Priority 2: Select the most efficient model for predicting customer churn.

# Priority 3: Evaluate the performance and update the model regularly for maintaining accuracy.

# %% [markdown]
# ---
# ## **Self-Assessment Section**

# %%
# Time Management Check
# Did you complete all sections within 35 minutes? (Yes/No): No

# Which section took the most time? Section B (Business Analysis)

# Which section was most challenging? Section B (Business Analysis)

# Confidence Level (1-10 scale):
# Section A (Data Understanding): 8
# Section B (Business Analysis): 6
# Section C (Research Methodology): 9
# Section D (Communication): 7

# Additional Comments:

# %% [markdown]
# ---
# ## **Submission Instructions**
#
# 1. **Save this notebook** with the filename: `YourName_Evoastra_Assessment.ipynb`
# 2. **Ensure all code cells have been executed** and answers are visible
# 3. **Double-check** that all sections are completed
#
# **Submission Confirmation:**
# - I confirm that I have completed this assessment independently
# - All my responses are my own original work
#
# **Digital Signature:** Karthikeya Sachin
# **Final Submission Time:** 1 hour

# %% [markdown]
# ---
# ## **Evaluation Criteria**
#
# **Scoring Breakdown:**
# - **Section A (Data Understanding):** 25 points
# - **Section B (Business Analysis):** 35 points
# - **Section C (Research Methodology):** 25 points
# - **Section D (Communication):** 15 points
# - **Total:** 100 points
#
# **Team Selection Criteria:**
# - **Team Lead:** Score ≥ 75 points + Strong Section D performance
# - **Co-Lead:** Score ≥ 65 points + Good Section D performance
# - **Team Member:** Successful completion of assessment
#
# ---
#
# *Good luck with your assessment! Focus on clear reasoning, accurate calculations, and practical business applications.*
